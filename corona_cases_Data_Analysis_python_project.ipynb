# %% [markdown]
# <a href="https://colab.research.google.com/github/isra9731/Final_project/blob/main/corona_cases_Data_Analysis_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <B>COUNTRY WISE COVID-19 DATA<B>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
opendata=pd.read_csv("/content/country_wise_latest.csv")
opendata
# Out:
#          Country/Region  Confirmed  ...  1 week % increase             WHO Region
# 0           Afghanistan      36263  ...               2.07  Eastern Mediterranean
# 1               Albania       4880  ...              17.00                 Europe
# 2               Algeria      27973  ...              18.07                 Africa
# 3               Andorra        907  ...               2.60                 Europe
# 4                Angola        950  ...              26.84                 Africa
# ..                  ...        ...  ...                ...                    ...
# 182  West Bank and Gaza      10621  ...              19.12  Eastern Mediterranean
# 183      Western Sahara         10  ...               0.00                 Africa
# 184               Yemen       1691  ...               4.45  Eastern Mediterranean
# 185              Zambia       4552  ...              36.86                 Africa
# ...

# %%
opendata.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
opendata.tail()
# Out:
#          Country/Region  Confirmed  ...  1 week % increase             WHO Region
# 182  West Bank and Gaza      10621  ...              19.12  Eastern Mediterranean
# 183      Western Sahara         10  ...               0.00                 Africa
# 184               Yemen       1691  ...               4.45  Eastern Mediterranean
# 185              Zambia       4552  ...              36.86                 Africa
# 186            Zimbabwe       2704  ...              57.85                 Africa
#
# [5 rows x 15 columns]

# %%
opendata.describe()       #used to fill in the null values
# Out:
#           Confirmed         Deaths  ...  1 week change  1 week % increase
# count  1.870000e+02     187.000000  ...     187.000000         187.000000
# mean   8.813094e+04    3497.518717  ...    9448.459893          13.606203
# std    3.833187e+05   14100.002482  ...   47491.127684          24.509838
# min    1.000000e+01       0.000000  ...     -47.000000          -3.840000
# 25%    1.114000e+03      18.500000  ...      49.000000           2.775000
# 50%    5.059000e+03     108.000000  ...     432.000000           6.890000
# 75%    4.046050e+04     734.000000  ...    3172.000000          16.855000
# max    4.290259e+06  148011.000000  ...  455582.000000         226.320000
#
# [8 rows x 13 columns]

# %%
opendata.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# RELATING THE VARIABLE WITH SCATTER PLOTS

# %%
sns.relplot(x="New cases",y="Deaths",data=opendata)

# %%
sns.relplot(x="New cases",y="New deaths",data=opendata)

# %%
sns.relplot(x="Country/Region",y="Deaths",hue="Recovered",data=opendata)

# %%
sns.pairplot(opendata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f687fe83aaea> in <module>()
# ----> 1 sns.pairplot(opendata)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2017     diag_kws.setdefault("legend", False)
#    2018     if diag_kind == "hist":
# -> 2019         grid.map_diag(histplot, **diag_kws)
#    2020     elif diag_kind == "kde":
#    2021         diag_kws.setdefault("fill", True)
#
# ...

# %%
opendata.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.relplot(x="New deaths",y="New cases",hue="Deaths", data=opendata)

# %%
sns.relplot(x="New deaths",y="New cases",kind="line", data=opendata)

# %%
sns.relplot(x="New cases",y="New deaths",kind="line", data=opendata)

# %%
sns.catplot(x="New deaths",y="New cases",data=opendata)    #catplot used for categorical data
